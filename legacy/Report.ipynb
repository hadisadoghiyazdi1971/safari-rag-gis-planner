# %% [markdown]
# بر اساس طرح کلی، برنامه به **۵ بخش اصلی** تقسیم می‌شود:
#
# ## 🏗️ **ساختار برنامه:**
#
# ### **۱. بخش پردازش داده‌ها (Data Processing)**
# ```python
# # وظایف:
# - تبدیل تصاویر به بردار (CLIP)
# - تولید توصیف متنی (BLIP)
# - خواندن و پردازش اکسل
# - یکپارچه‌سازی داده‌ها
# ```
#
# ### **۲. بخش ذخیره‌سازی (Vector Database)**
# ```python
# # وظایف:
# - ذخیره بردارهای تصویری و متنی
# - ایندکس‌گذاری برای جستجوی سریع
# - مدیریت متادیتا و مختصات جغرافیایی
# ```
#
# ### **۳. موتور جستجو (RAG Engine)**
# ```python
# # وظایف:
# - درک سوال کاربر
# - جستجوی چندوجهی (تصویر + متن + مکان)
# - رتبه‌بندی نتایج
# - بازیابی اطلاعات مرتبط
# ```
#
# ### **۴. موتور تحلیلی (LLM & Analytics)**
# ```python
# # وظایف:
# - تولید گزارش تحلیلی
# - پاسخ به سوالات پیچیده
# - تولید پیشنهادات و راهکارها
# ```
#
# ### **۵. رابط کاربری (Interactive Map UI)**
# ```python
# # وظایف:
# - نمایش نقشه تعاملی آفریقا
# - نمایش نقاط و تصاویر
# - امکان پرسش و پاسخ
# - نمایش گزارش‌ها
# ```
#
# ## 🔄 **گردش داده:**
# ```
# User Question → RAG Engine → Vector DB → LLM → Map UI → Final Output
# ```
#
# **آیا این ساختار را تأیید می‌کنید؟ می‌خواهید روی هر بخش دقیق‌تر شویم؟**
